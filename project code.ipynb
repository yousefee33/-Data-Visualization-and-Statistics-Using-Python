# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
DF=pd.read_csv("Diabetes Dataset.csv")

# %%
DF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # 1. Correlation Matrix Plot

# %%
plt.figure(figsize=(10, 8))
corr = DF.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 2. Scatter Plot (BloodPressure vs BMI)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=DF, x='BloodPressure', y='BMI')
plt.title('Scatter Plot: BloodPressure vs BMI')
plt.xlabel('Blood Pressure')
plt.ylabel('BMI')
plt.grid(True)
plt.show()

# %% [markdown]
# # 3. Distribution Plots for specified features

# %%
features = ['Pregnancies', 'SkinThickness', 'Age']
for feature in features:
    plt.figure(figsize=(8, 6))
    sns.histplot(DF[feature], kde=True, bins=20, color='blue', edgecolor='black')
    plt.title(f'Distribution Plot for {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %% [markdown]
# # 4. Pie Chart for Outcome (Diabetes or Not)

# %%
plt.figure(figsize=(6, 6))
outcome_counts = DF['Outcome'].value_counts()
outcome_labels = ['No Diabetes', 'Diabetes']
plt.pie(outcome_counts, labels=outcome_labels.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title("Pie Chart: Outcome (Diabetes or Not)")
plt.show()

# %% [markdown]
# # 5. Boxplots for specified features

# %%
boxplot_features = ['SkinThickness', 'DiabetesPedigreeFunction', 'BloodPressure']
for feature in boxplot_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=DF, x=feature)
    plt.title(f'Boxplot for {feature}')
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# # 6. Statistical Calculations

# %%
central_tendency = DF.describe().T[['mean', '50%', 'std']]
central_tendency.rename(columns={'50%': 'median'}, inplace=True)
central_tendency['mode'] = DF.mode().iloc[0]
print("Central Tendency (Mean, Median, Mode):")
print(central_tendency)
# Out:
# Central Tendency (Mean, Median, Mode):
#                                 mean    median         std    mode
# Pregnancies                 3.845052    3.0000    3.369578   1.000
# Glucose                   120.894531  117.0000   31.972618  99.000
# BloodPressure              69.105469   72.0000   19.355807  70.000
# SkinThickness              20.536458   23.0000   15.952218   0.000
# Insulin                    79.799479   30.5000  115.244002   0.000
# BMI                        31.992578   32.0000    7.884160  32.000
# DiabetesPedigreeFunction    0.471876    0.3725    0.331329   0.254
# Age                        33.240885   29.0000   11.760232  22.000
# Outcome                     0.348958    0.0000    0.476951   0.000

# %% [markdown]
# # Dispersion: Standard Deviation, Variance

# %%
dispersion = DF.std()
variance = DF.var()
dispersion_df = pd.DataFrame({'Standard Deviation': dispersion, 'Variance': variance})
print("\nDispersion (Standard Deviation, Variance):")
print(dispersion_df)
# Out:
# Dispersion (Standard Deviation, Variance):
#                           Standard Deviation      Variance
# Pregnancies                         3.369578     11.354056
# Glucose                            31.972618   1022.248314
# BloodPressure                      19.355807    374.647271
# SkinThickness                      15.952218    254.473245
# Insulin                           115.244002  13281.180078
# BMI                                 7.884160     62.159984
# DiabetesPedigreeFunction            0.331329      0.109779
# Age                                11.760232    138.303046
# Outcome                             0.476951      0.227483

# %% [markdown]
# # Minimum and Maximum Values

# %%
min_max = pd.concat([DF.min(), DF.max()], axis=1)
min_max.columns = ['Min', 'Max']
print("\nMinimum and Maximum Values:")
print(min_max)
# Out:
# Minimum and Maximum Values:
#                              Min     Max
# Pregnancies                0.000   17.00
# Glucose                    0.000  199.00
# BloodPressure              0.000  122.00
# SkinThickness              0.000   99.00
# Insulin                    0.000  846.00
# BMI                        0.000   67.10
# DiabetesPedigreeFunction   0.078    2.42
# Age                       21.000   81.00
# Outcome                    0.000    1.00
